# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("/praveen.csv")
df.head()
# Out:
#      data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0  05-01-2014  2014      5       14492     RDU       36      11032    CUN
# 1  06-01-2007  2007      6       13204     MCO       33      16085    YHZ
# 2  12-01-2005  2005     12       11433     DTW       43      10411    AUA
# 3  04-01-2003  2003      4       13487     MSP       63      16304    ZIH
# 4  12-01-2005  2005     12       12016     GUM        5      11138    CRK
#
#    fg_wac  airlineid carrier  carriergroup        type  Scheduled  Charter  \
# 0     148      19534      AM             0  Passengers          0      315
# 1     951      20364      C6             0  Passengers          0      683
# 2     277      20344      RD             1  Passengers          0     1010
# 3     148      20204      MG             1  Passengers          0      508
# 4     766      20312      TZ             1  Passengers          0       76
#
#    Total
# 0    315
# 1    683
# 2   1010
# 3    508
# 4     76

# %%
df.head(100)
# Out:
#       data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0   05-01-2014  2014      5       14492     RDU       36      11032    CUN
# 1   06-01-2007  2007      6       13204     MCO       33      16085    YHZ
# 2   12-01-2005  2005     12       11433     DTW       43      10411    AUA
# 3   04-01-2003  2003      4       13487     MSP       63      16304    ZIH
# 4   12-01-2005  2005     12       12016     GUM        5      11138    CRK
# ..         ...   ...    ...         ...     ...      ...        ...    ...
# 95  02-01-2008  2008      2       13303     MIA       33      10911    CCS
# 96  06-01-2003  2003      6       11433     DTW       43      13180    MBJ
# 97  06-01-2004  2004      6       10529     BDL       11      11032    CUN
# 98  08-01-2008  2008      8       11433     DTW       43      16271    YYZ
# 99  07-01-2004  2004      7       14057     PDX       92      16257    YYC
#
# ...

# %%
df.shape
# Out:
# (93453, 16)

# %%
df.describe()
# Out:
#                Year         Month    usg_apt_id       usg_wac     fg_apt_id  \
# count  93453.000000  93453.000000  93453.000000  93453.000000  93453.000000
# mean    2001.313398      6.127808  12823.755160     42.330155  13529.418114
# std        6.986186      3.507535   3160.222935     25.454543   2027.433420
# min     1990.000000      1.000000  10135.000000      1.000000  10125.000000
# 25%     1995.000000      3.000000  11433.000000     22.000000  11628.000000
# 50%     2002.000000      6.000000  12892.000000     33.000000  13605.000000
# 75%     2007.000000      9.000000  13930.000000     63.000000  15513.000000
# max     2015.000000     12.000000  99999.000000     93.000000  16575.000000
#
#              fg_wac     airlineid  carriergroup  Scheduled       Charter  \
# count  93453.000000  93453.000000  93453.000000    93453.0  93453.000000
# mean     429.835896  20216.250607      0.623383        0.0   1093.057077
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93453 entries, 0 to 93452
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   data_dte      93453 non-null  object
#  1   Year          93453 non-null  int64
#  2   Month         93453 non-null  int64
#  3   usg_apt_id    93453 non-null  int64
#  4   usg_apt       93453 non-null  object
#  5   usg_wac       93453 non-null  int64
#  6   fg_apt_id     93453 non-null  int64
#  7   fg_apt        93453 non-null  object
#  8   fg_wac        93453 non-null  int64
#  9   airlineid     93453 non-null  int64
#  10  carrier       92687 non-null  object
#  11  carriergroup  93453 non-null  int64
#  12  type          93453 non-null  object
#  13  Scheduled     93453 non-null  int64
#  14  Charter       93453 non-null  int64
#  15  Total         93453 non-null  int64
# dtypes: int64(11), object(5)
# memory usage: 11.4+ MB

# %%
df.isnull()
# Out:
#        data_dte   Year  Month  usg_apt_id  usg_apt  usg_wac  fg_apt_id  \
# 0         False  False  False       False    False    False      False
# 1         False  False  False       False    False    False      False
# 2         False  False  False       False    False    False      False
# 3         False  False  False       False    False    False      False
# 4         False  False  False       False    False    False      False
# ...         ...    ...    ...         ...      ...      ...        ...
# 93448     False  False  False       False    False    False      False
# 93449     False  False  False       False    False    False      False
# 93450     False  False  False       False    False    False      False
# 93451     False  False  False       False    False    False      False
# 93452     False  False  False       False    False    False      False
#
#        fg_apt  fg_wac  airlineid  carrier  carriergroup   type  Scheduled  \
# ...

# %%
df.isnull().sum()
# Out:
# data_dte          0
# Year              0
# Month             0
# usg_apt_id        0
# usg_apt           0
# usg_wac           0
# fg_apt_id         0
# fg_apt            0
# fg_wac            0
# airlineid         0
# carrier         766
# carriergroup      0
# type              0
# Scheduled         0
# Charter           0
# Total             0
# dtype: int64

# %%
df["carrier"].fillna("No carrier", inplace = True) 
    
df.isnull().sum()
# Out:
# data_dte        0
# Year            0
# Month           0
# usg_apt_id      0
# usg_apt         0
# usg_wac         0
# fg_apt_id       0
# fg_apt          0
# fg_wac          0
# airlineid       0
# carrier         0
# carriergroup    0
# type            0
# Scheduled       0
# Charter         0
# Total           0
# dtype: int64

# %%
df=df.dropna(axis=0,how="any")
df.isnull().sum()
# Out:
# data_dte        0
# Year            0
# Month           0
# usg_apt_id      0
# usg_apt         0
# usg_wac         0
# fg_apt_id       0
# fg_apt          0
# fg_wac          0
# airlineid       0
# carrier         0
# carriergroup    0
# type            0
# Scheduled       0
# Charter         0
# Total           0
# dtype: int64

# %%
df1=df.head(100)
df1
# Out:
#       data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0   05-01-2014  2014      5       14492     RDU       36      11032    CUN
# 1   06-01-2007  2007      6       13204     MCO       33      16085    YHZ
# 2   12-01-2005  2005     12       11433     DTW       43      10411    AUA
# 3   04-01-2003  2003      4       13487     MSP       63      16304    ZIH
# 4   12-01-2005  2005     12       12016     GUM        5      11138    CRK
# ..         ...   ...    ...         ...     ...      ...        ...    ...
# 95  02-01-2008  2008      2       13303     MIA       33      10911    CCS
# 96  06-01-2003  2003      6       11433     DTW       43      13180    MBJ
# 97  06-01-2004  2004      6       10529     BDL       11      11032    CUN
# 98  08-01-2008  2008      8       11433     DTW       43      16271    YYZ
# 99  07-01-2004  2004      7       14057     PDX       92      16257    YYC
#
# ...

# %%
x=df1["Year"]
y=df1["Month"]
style1 = {'family':'serif','color':'darkred','size':25}
style2= {'family':'serif','color':'blue','size':20}
style3={'family':'serif','color':'green','size':50}
plt.title("Simple plotting",fontdict=style3)
plt.xlabel("year",fontdict=style1)
plt.ylabel("Month",fontdict=style2)
plt.grid()
plt.plot(x,y)

# %%
plt.plot(y, marker = 'o', ms = 20, mec = 'r')

# %%
plt.scatter(x,y,color='green')

# %%
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))
plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')
plt.colorbar()

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 100 artists>

# %%
plt.barh(x,y,color="green")
# Out:
# <BarContainer object of 100 artists>

# %%
plt.bar(x, y, width = 0.2)
# Out:
# <BarContainer object of 100 artists>

# %%
plt.barh(x, y, height= 0.2,color="green")
# Out:
# <BarContainer object of 100 artists>

# %%
plt.hist(x)
# Out:
# (array([24.,  8., 13., 22., 10., 12., 10.,  0.,  0.,  1.]),
#  array([2001. , 2002.3, 2003.6, 2004.9, 2006.2, 2007.5, 2008.8, 2010.1,
#         2011.4, 2012.7, 2014. ]),
#  <a list of 10 Patch objects>)

# %%
plt.pie(y)
plt.legend()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
plt.stem(x,y)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """Entry point for launching an IPython kernel.
# <StemContainer object of 3 artists>

# %%
plt.polar(x,y,color='green')

# %%
plt.fill_between(x,y)

# %%
plt.fill_betweenx(x,y)
